# %% [markdown]
# <a href="https://colab.research.google.com/github/NhuY26/T-o-t-i-kho-n-Github-xu-t-file-Colab/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(125):
  print(" Yêu bé Hòa nhìu :3 ")
print(" by Ys =))")
# Out:
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
#  Yêu bé Hòa nhìu :3
# ...
